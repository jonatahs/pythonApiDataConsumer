# %% [markdown]
# # <font color = 'blue'>Python API Data Consumer</font>
#
# Project made in Python to consume data from the IEEE API.
#
#    **What is the IEEE?**
#
# The IEEE is a scientific community that seeks to innovate and inform the community through publications, conferences and scientific articles focused on technology, the IEEE today is a reliable "voice" for information in these areas.
#
#    **What does the API return?**
#
#    The API is a **PUBLIC API** that returns information from articles and publications on certain subjects chosen by us, in this project the subject of the articles that I will be requesting in the API refers to Big Data and Data Quality.
#
# <hr>
#
# ##### <font color = 'red'>Developed by Jonathan Silva Sales de Oliveira</font>
#
# ##### <font color = 'red'>My social networks:</font>
# - Personal Page : https://jonatahs.github.io/
# - Linkedin : https://www.linkedin.com/in/jonathansilvasales/
# - Medium: https://medium.com/@jonathansalesjobs
# - Email : jonathansalesjobs@gmail.com
# <hr>

# %%
# Imports
import json
from urllib import response
import requests
import pandas as pd
from pandas.io.json import json_normalize
import flatten_json
from apiKey import apiKey

# %% [markdown]
# ### <font color="red">The API key is stored in a variable in an external file for security reasons, the file is not in this repository. 😃</font>

# %%
# url with apikey 
url = apiKey
# api connection
response = requests.get(url)
# print connection api, if print 200, the api its working!
print(f'Reponse API:{response}')

print('-----------------------------')
print('\n')
print('Datas from API')
# reading datas from api
data = response.json()
#print json
print(data)
# Out:
# Reponse API:<Response [200]>
# -----------------------------
#
#
# Datas from API
# {'total_records': 2033, 'total_searched': 5708980, 'articles': [{'doi': '10.1109/BigData.Congress.2013.13', 'title': 'A Discussion of Privacy Challenges in User Profiling with Big Data Techniques: The EEXCESS Use Case', 'publisher': 'IEEE', 'isbn': '978-0-7695-5006-0', 'issn': '2379-7703', 'rank': 1, 'authors': {'authors': [{'affiliation': 'CNRS, INSA-Lyon, LIRIS, UMR5205, University of Lyon, France', 'authorUrl': 'https://ieeexplore.ieee.org/author/37657723100', 'id': 37657723100, 'full_name': 'Omar Hasan', 'author_order': 1}, {'affiliation': 'CNRS, INSA-Lyon, LIRIS, UMR5205, University of Lyon, France', 'authorUrl': 'https://ieeexplore.ieee.org/author/37283164500', 'id': 37283164500, 'full_name': 'Benjamin Habegger', 'author_order': 2}, {'affiliation': 'CNRS, INSA-Lyon, LIRIS, UMR5205, University of Lyon, France', 'authorUrl': 'https://ieeexplore.ieee.org/author/37299601000', 'id': 37299601000, 'full_name': 'Lionel Brunie', 'author_order': 3}, {'affiliation': 'CNRS, INSA-Lyon, LIRIS, UMR5205, University of Lyon, France', 'authorUrl': 'https://ieeexplore.ieee.org/author/37321054000', 'id': 37321054000, 'full_name': 'Nadia Bennani', 'author_order': 4}, {'affiliation': 'Department of Computer Technology, University of Milan, Italy', 'authorUrl': 'https://ieeexplore.ieee.org/author/37271667500', 'id': 37271667500, 'full_name': 'Ernesto Damiani', 'author_order': 5}]}, 'access_type': 'LOCKED', 'content_type': 'Conferences', 'abstract': 'User profiling is the process of collecting information about a user in order to construct their profile. The information in a user profile may include various attributes of a user such as geographical location, academic and professional background, membership in groups, interests, preferences, opinions, etc. Big data techniques enable collecting accurate and rich information for user profiles, in particular due to their ability to process unstructured as well as structured information in high volumes from multiple sources. Accurate and rich user profiles are important for applications such as recommender systems, which try to predict elements that a user has not yet considered but may find useful. The information contained in user profiles is personal and thus there are privacy issues related to user profiling. In this position paper, we discuss user profiling with big data techniques and the associated privacy challenges. We also discuss the ongoing EU-funded EEXCESS project as a concrete example of constructing user profiles with big data techniques and the approaches being considered for preserving user privacy.', 'article_number': '6597115', 'pdf_url': 'https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=6597115', 'html_url': 'https://ieeexplore.ieee.org/document/6597115/', 'abstract_url': 'https://ieeexplore.ieee.org/document/6597115/', 'publication_title': '2013 IEEE International Congress on Big Data', 'conference_location': 'Santa Clara, CA, USA', 'conference_dates': '27 June-2 July 2013', 'publication_number': 6596172, 'is_number': 6597101, 'publication_year': 2013, 'publication_date': '27 June-2 July 2013', 'start_page': '25', 'end_page': '30', 'citing_paper_count': 36, 'citing_patent_count': 0, 'index_terms': {'ieee_terms': {'terms': ['Privacy', 'Information management', 'Data handling', 'Data storage systems', 'Context', 'Data privacy', 'Recommender systems']}, 'author_terms': {'terms': ['User profiling', 'recommender systems', 'big data', 'privacy', 'EEXCESS']}}, 'isbn_formats': {'isbns': [{'format': 'Electronic ISBN', 'value': '978-0-7695-5006-0', 'isbnType': 'New-2005'}]}}, {'doi': '10.1109/BigData.Congress.2013.15', 'title': 'Engineering Privacy for Big Data Apps with the Unified Modeling Language', 'publisher': 'IEEE', 'isbn': '978-0-7695-5006-0', 'issn': '2379-7703', 'rank': 2, 'authors': {'authors': [{'affiliation': "Sobey School of Business, Saint Mary's University, Halifax, NS, Canada", 'authorUrl': 'https://ieeexplore.ieee.org/author/37282818200', 'id': 37282818200, 'ful ...

# %%
# Select articles in json
articlesList = data['articles']
articles = [i for i in articlesList]

# %%
doiValue = [doi.get('doi') for doi in articles]
titleValue = [title.get('title') for title in articles]
publisherValue = [publisher.get('publisher') for publisher in articles]
pdfValue = [pdf.get('pdf_url') for pdf in articles]
abstractValue = [abstract.get('abstract') for abstract in articles]
rankValue = [rank.get('rank') for rank in articles]

# %%
articlesdf = pd.DataFrame({'doi':doiValue,'title':titleValue,'rank':rankValue,'pdf_url':pdfValue,'abstract':abstractValue,'publisher':publisherValue})
articlesdf
# Out:
#                                  doi  \
# 0   10.1109/BigData.Congress.2013.13
# 1   10.1109/BigData.Congress.2013.15
# 2   10.1109/BigData.Congress.2013.16
# 3   10.1109/BigData.Congress.2013.17
# 4   10.1109/BigData.Congress.2013.18
# 5   10.1109/BigData.Congress.2013.21
# 6   10.1109/BigData.Congress.2013.23
# 7   10.1109/BigData.Congress.2013.24
# 8   10.1109/BigData.Congress.2013.25
# 9   10.1109/BigData.Congress.2013.39
# 10  10.1109/BigData.Congress.2013.78
# 11  10.1109/BigData.Congress.2013.60
# 12  10.1109/BigData.Congress.2013.61
# 13  10.1109/BigData.Congress.2013.65
# 14  10.1109/BigData.Congress.2013.66
# 15  10.1109/BigData.Congress.2013.68
# 16  10.1109/BigData.Congress.2013.70
# 17  10.1109/BigData.Congress.2013.79
# 18      10.1109/BigData.2013.6691547
# 19      10.1109/BigData.2013.6691549
# 20      10.1109/BigData.2013.6691551
# 21      10.1109/BigData.2013.6691553
# 22      10.1109/BigData.2013.6691556
# 23      10.1109/BigData.2013.6691559
# 24      10.1109/BigData.2013.6691561
# 25      10.1109/BigData.2013.6691567
# 26      10.1109/BigData.2013.6691569
# 27      10.1109/BigData.2013.6691570
# 28      10.1109/BigData.2013.6691571
# 29      10.1109/BigData.2013.6691592
# 30      10.1109/BigData.2013.6691612
# 31      10.1109/BigData.2013.6691618
# 32      10.1109/BigData.2013.6691624
# 33      10.1109/BigData.2013.6691627
# 34      10.1109/BigData.2013.6691630
# 35      10.1109/BigData.2013.6691631
# 36      10.1109/BigData.2013.6691632
# 37      10.1109/BigData.2013.6691643
# 38      10.1109/BigData.2013.6691653
# 39      10.1109/BigData.2013.6691666
#
#                                                 title  rank  \
# 0   A Discussion of Privacy Challenges in User Pro...     1
# 1   Engineering Privacy for Big Data Apps with the...     2
# 2   Milieu: Lightweight and Configurable Big Data ...     3
# 3   Consistent Process Mining over Big Data Triple...     4
# 4   Towards Cloud-Based Analytics-as-a-Service (CL...     5
# 5   Towards a Quality-centric Big Data Architectur...     6
# 6   Multi-resolution Social Network Community Iden...     7
# 7      Approximate Incremental Big-Data Harmonization     8
# 8   Countering the Concept-Drift Problem in Big Da...     9
# 9   Challenges of Privacy Protection in Big Data A...    10
# 10         Techniques for Graph Analytics on Big Data    11
# 11  Service-Generated Big Data and Big Data-as-a-S...    12
# 12  Big Data Infrastructure for Active Situation A...    13
# 13    Analysis of Technology Trends Based on Big Data    14
# 14  Storage Mining: Where IT Management Meets Big ...    15
# 15  Distributed Stochastic Aware Random Forests --...    16
# 16  The Knowledge Service Project in the Era of Bi...    17
# 17  Effective Interpretation of Bucket Testing Res...    18
# 18             Security — A big question for big data    19
# 19  Communication efficient algorithms for fundame...    20
# 20         P-DOT: A model of computation for big data    21
# 21  Elastic algorithms for guaranteeing quality mo...    22
# 22  Storing and manipulating environmental big dat...    23
# 23  Building a generic platform for big sensor dat...    24
# 24  clusiVAT: A mixed visual/numerical clustering ...    25
# 25          Algebraic dataflows for big data analysis    26
# 26  Robot: An efficient model for big data storage...    27
# 27  Multilevel Active Storage for big data applica...    28
# 28  GPU accelerated item-based collaborative filte...    29
# 29  Using pattern-models to guide SSD deployment f...    30
# 30  Classification of big velocity data via cross-...    31
# 31  Efficient large graph pattern mining for big d...    32
# 32  A Higher-order data flow model for heterogeneo...    33
# 33   Malicious URL filtering — A big data application    34
# 34        Breaking the Arc: Risk control for Big Data    35
# 35  The BTWorld use case for big data analytics: D...    36
# 36  Modeling heterogeneous time series dynamics to...    37
# 37  Demand response targeting using big data analy...    38
# 38  Big data analytics on high Velocity streams: A...    39
# 39  Visualization and rhetoric: Key concerns for u...    40
#
#                                               pdf_url  \
# 0   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 1   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 2   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 3   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 4   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 5   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 6   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 7   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 8   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 9   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 10  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 11  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 12  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 13  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 14  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 15  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 16  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 17  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 18  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 19  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 20  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 21  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 22  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 23  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 24  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 25  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 26  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 27  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 28  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 29  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 30  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 31  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 32  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 33  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 34  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 35  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 36  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 37  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 38  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 39  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
#
#                                              abstract publisher
# 0   User profiling is the process of collecting in...      IEEE
# 1   This paper describes proposed privacy extensio...      IEEE
# 2   The volume and complexity of data produced and...      IEEE
# 3   'Big Data' techniques are often adopted in cro...      IEEE
# 4   Data Analytics has proven its importance in kn...      IEEE
# 5   As the Internet of Things (IoT) paradigm gains...      IEEE
# 6   Community identification in social networks is...      IEEE
# 7   The needs of `big data analytics' increasingly...      IEEE
# 8   How to efficiently uncover the knowledge hidde...      IEEE
# 9   The big data paradigm implies that almost ever...      IEEE
# 10  Graphs enjoy profound importance because of th...      IEEE
# 11  With the prevalence of service computing and c...      IEEE
# 12  Awareness computing aims at our final goal in ...      IEEE
# 13  The paper suggests a method for analyzing tech...      IEEE
# 14  The emerging paradigm shift to cloud based dat...      IEEE
# 15  Some top data mining algorithms, as ensemble c...      IEEE
# 16  The integration of industrialization and IT ap...      IEEE
# 17  Bucket testing is a common practice in the int...      IEEE
# 18  Summary form only given. Big data implies perf...      IEEE
# 19  Big Data applications often store or obtain th...      IEEE
# 20  In response to the high demand of big data ana...      IEEE
# 21  When mining large data volumes in big data app...      IEEE
# 22  JASMIN is a super-data-cluster designed to pro...      IEEE
# 23  The drive toward smart cities alongside the ri...      IEEE
# 24  Recent algorithmic and computational improveme...      IEEE
# 25  Analyzing big data requires the support of dat...      IEEE
# 26  It is well-known that with the explosive growt...      IEEE
# 27  Given the growing importance of supporting dat...      IEEE
# 28  Recommendation systems are a popular marketing...      IEEE
# 29  Flash-memory based Solid State Drives (SSDs) e...      IEEE
# 30  Many classification techniques work well only ...      IEEE
# 31  Mining big graph data is an important problem ...      IEEE
# 32  We introduce a data flow model that supports h...      IEEE
# 33  Malicious URLs have become a channel for Inter...      IEEE
# 34  The use of Big Data technologies and analytics...      IEEE
# 35  The commoditization of big data analytics, tha...      IEEE
# 36  While a massive amount of time series can now ...      IEEE
# 37  The drive towards more sustainable power suppl...      IEEE
# 38  Big data management is often characterized by ...      IEEE
# 39  Visualization of data mining results is the li...      IEEE

# %%
articlesdf.to_parquet('IEEE.parquet',index=False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\03_estudos\python\MBA\pythonApiConsumer.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/03_estudos/python/MBA/pythonApiConsumer.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> articlesdf.to_parquet('IEEE.parquet',index=False)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:2835, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2749 """
#    2750 Write a DataFrame to the binary parquet format.
#    2751
#    (...)
#    2831 >>> content = f.read()
#    2832 """
#    2833 from pandas.io.parquet import to_parquet
# -> 2835 return to_parquet(
#    2836     self,
#    2837     path,
#    2838     engine,
#    2839     compression=compression,
#    2840     index=index,
#    2841     partition_cols=partition_cols,
#    2842     storage_options=storage_options,
#    2843     **kwargs,
#    2844 )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parquet.py:416, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     414 if isinstance(partition_cols, str):
#     415     partition_cols = [partition_cols]
# --> 416 impl = get_engine(engine)
#     418 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     420 impl.write(
#     421     df,
#     422     path_or_buf,
#    (...)
#     427     **kwargs,
#     428 )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parquet.py:52, in get_engine(engine)
#      49         except ImportError as err:
#      50             error_msgs += "\n - " + str(err)
# ---> 52     raise ImportError(
#      53         "Unable to find a usable engine; "
#      54         "tried using: 'pyarrow', 'fastparquet'.\n"
#      55         "A suitable version of "
#      56         "pyarrow or fastparquet is required for parquet "
#      57         "support.\n"
#      58         "Trying to import the above resulted in these errors:"
#      59         f"{error_msgs}"
#      60     )
#      62 if engine == "pyarrow":
#      63     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %%
articlesdf.to_csv('IEEE.csv',index=False)
